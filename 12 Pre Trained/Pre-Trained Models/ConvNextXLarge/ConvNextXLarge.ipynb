# %%
import keras
from keras.applications.convnext import ConvNeXtXLarge
from keras.applications.convnext import preprocess_input, decode_predictions
import numpy as np

# %%
# Load the ConvNeXt-XLarge model pre-trained on ImageNet
model = ConvNeXtXLarge(weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/convnext/convnext_xlarge.h5
# 1401457568/1401457568 ━━━━━━━━━━━━━━━━━━━━ 16s 0us/step

# %% [markdown]
# ### Test on elephant image

# %%
# Load and preprocess the image
img_path = '/content/elephant image.jpg'
img = keras.utils.load_img(img_path, target_size=(224, 224)) #target size of image net is pre-defined - can see in kaggle
x = keras.utils.img_to_array(img) #conversion image to array - use numpy
x = np.expand_dims(x, axis=0)  #dimension of array
x = preprocess_input(x)  #pre-process

# %%
# Predict the probabilities for the top classes
preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])  #top3 - means zayada close kin teen se aya hai
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 17s 17s/step
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 35363/35363 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Predicted: [('n02504458', 'African_elephant', 0.470491), ('n02504013', 'Indian_elephant', 0.25391448), ('n01871265', 'tusker', 0.22962046)]

# %% [markdown]
# ### Test on strawberry image

# %%
img_path = '/content/strawberry image.jpg'
img = keras.utils.load_img(img_path, target_size=(224, 224))
x = keras.utils.img_to_array(img)  #conversion image to array - use numpy
x = np.expand_dims(x, axis=0)      #dimension of array
x = preprocess_input(x)  #pre-process

# %%
preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])  #top3 - means zayada close kin teen se aya hai
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step
# Predicted: [('n07745940', 'strawberry', 0.9580083), ('n07753275', 'pineapple', 0.00016124776), ('n13044778', 'earthstar', 0.0001544628)]

# %% [markdown]
# ### Test on tomato image

# %%
img_path = '/content/tomato image.jpg'
img = keras.utils.load_img(img_path, target_size=(224, 224))
x = keras.utils.img_to_array(img)  #conversion image to array - use numpy
x = np.expand_dims(x, axis=0)      #dimension of array
x = preprocess_input(x)  #pre-process

# %%
preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])  #top3 - means zayada close kin teen se aya hai
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/step
# Predicted: [('n07718472', 'cucumber', 0.33461928), ('n07720875', 'bell_pepper', 0.118463024), ('n07747607', 'orange', 0.02792756)]

# %% [markdown]
# ### ConvNextXLarge model architecture

# %% [markdown]
# Model shows pretty large image - that's why code is written as comment. \
# To see image check out model.png

# %%
# Visualize the model architecture
# from keras.utils import plot_model
# plot_model(model)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model

# Visualize the submodel
# Simplify the model visualization with lower dpi and horizontal layout
plot_model(small_model, to_file='small_model_plot.png', show_shapes=True, dpi=50, rankdir='LR')

# %% [markdown]
# ---
#
#
# This shows top 5 layers of the architecture

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model

# Example: Visualizing only up to the 5th layer
small_model = Model(inputs=model.input, outputs=model.layers[5].output)
plot_model(small_model, to_file='small_model_vertical_plot.png', show_shapes=True, dpi=50)

# %%
# model.summary()
