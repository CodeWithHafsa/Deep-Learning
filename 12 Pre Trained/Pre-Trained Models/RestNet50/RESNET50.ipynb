# %%
import keras
from keras.applications.resnet50 import ResNet50
from keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

# %%
# Load the RESNET50 model pre-trained on ImageNet
model = ResNet50(weights='imagenet')
# Out:
# ...
# 102967424/102967424 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# ### Test on elephant image

# %%
# Load and preprocess the ima
img_path = '/content/elephant.jpg'
img = keras.utils.load_img(img_path, target_size=(224, 224))   #target size of image net is pre-defined - can see in kaggle
x = keras.utils.img_to_array(img)  #conversion image to array - use numpy
x = np.expand_dims(x, axis=0)      #dimension of array
x = preprocess_input(x)  #pre-process

# %%
preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])  #top3 - means zayada close kin teen se aya hai
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# ...
# 35363/35363 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Predicted: [('n02504458', 'African_elephant', 0.6736719), ('n01871265', 'tusker', 0.23056589), ('n02504013', 'Indian_elephant', 0.095703304)]

# %%
# top 10 means first 10 categories

# %% [markdown]
# ### Test on strawberry image

# %%
img_path = '/content/strawberry image.jpg'
img = keras.utils.load_img(img_path, target_size=(224, 224))
x = keras.utils.img_to_array(img)  #conversion image to array - use numpy
x = np.expand_dims(x, axis=0)      #dimension of array
x = preprocess_input(x)  #pre-process

# %%
preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])  #top3 - means zayada close kin teen se aya hai
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step
# Predicted: [('n07745940', 'strawberry', 0.9999182), ('n07753275', 'pineapple', 2.1945081e-05), ('n07836838', 'chocolate_sauce', 7.769014e-06)]

# %% [markdown]
# ### Test on tomato image

# %%
img_path = '/content/tomato image.jpg'
img = keras.utils.load_img(img_path, target_size=(224, 224))
x = keras.utils.img_to_array(img)  #conversion image to array - use numpy
x = np.expand_dims(x, axis=0)      #dimension of array
x = preprocess_input(x)  #pre-process

# %%
preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])  #top3 - means zayada close kin teen se aya hai
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# Predicted: [('n07745940', 'strawberry', 0.62681305), ('n07720875', 'bell_pepper', 0.07264107), ('n12620546', 'hip', 0.07148412)]

# %% [markdown]
# ### Resnet 50 model architecture

# %% [markdown]
# Model shows pretty large image - that's why code is written as comment. \
# To see image check out model.png

# %%
# from keras.utils import plot_model
# plot_model(model)
#it defined architecture - that people made by using code (by hit and trail method)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model

# Assuming 'model' is your existing model and you want to create a smaller model
small_model = Model(inputs=model.input, outputs=model.layers[10].output)

# Plotting the smaller model
plot_model(small_model, to_file='small_model_plot.png', show_shapes=True, dpi=50)
